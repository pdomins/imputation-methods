# %%
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer

# %%
qual_cols = { "age", "TSH", "T3", "TT4", "T4U", "FTI", "TBG" }
cat_cols = { "sex", "on_thyroxine", "on_antithyroid_meds", "sick", "pregnant", "thyroid_surgery", "I131_treatment", "lithium", "goitre", "tumor", "psych", "referral_source", "target" }

# %%
remove_qual_cols = { "TBG" }
remove_cat_cols = set()

# %%
k = 10
neighbours = 2

# %%
seed = 42

# %%
random_generator = np.random.default_rng(seed=seed)

# %%
sel_qual_cols = list(qual_cols.difference(remove_qual_cols))
sel_cat_cols = list(cat_cols.difference(remove_cat_cols))
display(sel_qual_cols)
display(sel_cat_cols)
# Out:
# ['FTI', 'T4U', 'T3', 'TSH', 'TT4', 'age']
# ['sex',
#  'I131_treatment',
#  'psych',
#  'on_thyroxine',
#  'target',
#  'goitre',
#  'lithium',
#  'pregnant',
#  'tumor',
#  'referral_source',
#  'sick',
#  'thyroid_surgery',
#  'on_antithyroid_meds']

# %%
df = pd.read_csv("./data/thyroidDF.csv")
df
# Out:
#       age sex on_thyroxine query_on_thyroxine on_antithyroid_meds sick  \
# 0      29   F            f                  f                   f    f
# 1      29   F            f                  f                   f    f
# 2      41   F            f                  f                   f    f
# 3      36   F            f                  f                   f    f
# 4      32   F            f                  f                   f    f
# ...   ...  ..          ...                ...                 ...  ...
# 9167   56   M            f                  f                   f    f
# 9168   22   M            f                  f                   f    f
# 9169   69   M            f                  f                   f    f
# 9170   47   F            f                  f                   f    f
# 9171   31   M            f                  f                   f    f
#
#      pregnant thyroid_surgery I131_treatment query_hypothyroid  ...    TT4  \
# 0           f               f              f                 t  ...    NaN
# 1           f               f              f                 f  ...  128.0
# 2           f               f              f                 f  ...    NaN
# 3           f               f              f                 f  ...    NaN
# 4           f               f              f                 f  ...    NaN
# ...       ...             ...            ...               ...  ...    ...
# 9167        f               f              f                 f  ...   64.0
# 9168        f               f              f                 f  ...   91.0
# 9169        f               f              f                 f  ...  113.0
# 9170        f               f              f                 f  ...   75.0
# 9171        f               f              f                 t  ...   66.0
#
#      T4U_measured   T4U FTI_measured   FTI TBG_measured   TBG  \
# 0               f   NaN            f   NaN            f   NaN
# 1               f   NaN            f   NaN            f   NaN
# 2               f   NaN            f   NaN            t  11.0
# 3               f   NaN            f   NaN            t  26.0
# 4               f   NaN            f   NaN            t  36.0
# ...           ...   ...          ...   ...          ...   ...
# 9167            t  0.83            t  77.0            f   NaN
# 9168            t  0.92            t  99.0            f   NaN
# 9169            t  1.27            t  89.0            f   NaN
# 9170            t  0.85            t  88.0            f   NaN
# 9171            t  1.02            t  65.0            f   NaN
#
#       referral_source target  patient_id
# 0               other      -   840801013
# 1               other      -   840801014
# 2               other      -   840801042
# 3               other      -   840803046
# 4               other      S   840803047
# ...               ...    ...         ...
# 9167              SVI      -   870119022
# 9168              SVI      -   870119023
# 9169              SVI      I   870119025
# 9170            other      -   870119027
# 9171            other      -   870119035
#
# [9172 rows x 31 columns]

# %%
df.dropna()
# Out:
#       age sex on_thyroxine query_on_thyroxine on_antithyroid_meds sick  \
# 167    40   F            f                  f                   f    f
# 5256   35   F            f                  f                   f    f
# 6044   77   F            f                  f                   f    f
# 6045   73   M            f                  f                   f    f
# 6747   77   F            f                  f                   f    f
# 6773   74   F            f                  f                   f    f
# 6862   60   M            f                  f                   f    f
# 6863   66   F            f                  f                   f    f
# 6880   42   F            f                  f                   f    f
# 6934   29   F            f                  f                   f    f
# 7097   35   M            f                  f                   f    f
# 7101   44   F            f                  f                   f    f
# 7103   78   F            f                  f                   f    f
# 7190   28   F            f                  f                   f    f
# 7239   58   M            f                  f                   f    f
# 7254   46   F            f                  f                   f    f
# 7356   97   M            f                  f                   f    f
# 7591   57   F            f                  f                   f    f
# 7733   60   F            f                  f                   f    f
# 8116   24   F            t                  f                   f    f
#
#      pregnant thyroid_surgery I131_treatment query_hypothyroid  ...    TT4  \
# 167         f               f              f                 f  ...    3.9
# 5256        f               t              f                 f  ...   73.0
# 6044        f               f              f                 f  ...  120.0
# 6045        f               f              f                 f  ...   89.0
# 6747        f               f              f                 f  ...  131.0
# 6773        f               f              f                 f  ...  116.0
# 6862        f               f              f                 f  ...   92.0
# 6863        f               f              f                 f  ...  138.0
# 6880        f               f              f                 f  ...  106.0
# 6934        f               f              f                 f  ...  122.0
# 7097        f               f              f                 f  ...   97.0
# 7101        f               f              f                 f  ...  135.0
# 7103        f               f              f                 f  ...  120.0
# 7190        f               f              f                 f  ...   75.0
# 7239        f               f              f                 f  ...  161.0
# 7254        f               f              f                 f  ...  116.0
# 7356        f               f              f                 f  ...   93.0
# 7591        f               f              f                 f  ...  110.0
# 7733        f               f              f                 f  ...  139.0
# 8116        f               f              f                 f  ...  176.0
#
#      T4U_measured   T4U FTI_measured    FTI TBG_measured   TBG  \
# 167             t  0.83            t    5.0            t  28.0
# 5256            t  1.16            t   63.0            t  37.0
# 6044            t  0.96            t  124.0            t  45.0
# 6045            t  0.74            t  119.0            t  24.0
# 6747            t  1.04            t  126.0            t  25.0
# 6773            t  0.81            t  143.0            t  22.0
# 6862            t  0.84            t  110.0            t  21.0
# 6863            t  0.80            t  173.0            t  15.0
# 6880            t  0.98            t  108.0            t  27.0
# 6934            t  1.14            t  107.0            t  36.0
# 7097            t  0.85            t  114.0            t  30.0
# 7101            t  1.01            t  135.0            t  32.0
# 7103            t  0.96            t  125.0            t  35.0
# 7190            t  0.82            t   92.0            t  21.0
# 7239            t  1.27            t  127.0            t  86.0
# 7254            t  0.80            t  145.0            t  22.0
# 7356            t  0.89            t  104.0            t  29.0
# 7591            t  0.88            t  125.0            t  26.0
# 7733            t  1.09            t  128.0            t  21.0
# 8116            t  1.07            t  164.0            t  28.0
#
#       referral_source target  patient_id
# 167             other      F   840827019
# 5256            other      -   851128040
# 6044              SVI      -   860305064
# 6045              SVI      -   860305065
# 6747              SVI      K   860702030
# 6773              SVI      -   860703046
# 6862            other      -   860710043
# 6863              SVI      -   860710044
# 6880            other      -   860711039
# 6934              SVI      -   860717007
# 7097              SVI      -   860729023
# 7101              SVI      -   860729072
# 7103              SVI      -   860729075
# 7190              SVI      -   860805027
# 7239              SVI      I   860807059
# 7254              SVI      -   860808041
# 7356              SVI      -   860815049
# 7591            other      -   860902004
# 7733              SVI      G   860912032
# 8116            other      N   861015018
#
# [20 rows x 31 columns]

# %%
df[sel_qual_cols]
# Out:
#        FTI   T4U   T3  TSH    TT4  age
# 0      NaN   NaN  NaN  0.3    NaN   29
# 1      NaN   NaN  1.9  1.6  128.0   29
# 2      NaN   NaN  NaN  NaN    NaN   41
# 3      NaN   NaN  NaN  NaN    NaN   36
# 4      NaN   NaN  NaN  NaN    NaN   32
# ...    ...   ...  ...  ...    ...  ...
# 9167  77.0  0.83  NaN  NaN   64.0   56
# 9168  99.0  0.92  NaN  NaN   91.0   22
# 9169  89.0  1.27  NaN  NaN  113.0   69
# 9170  88.0  0.85  NaN  NaN   75.0   47
# 9171  65.0  1.02  NaN  NaN   66.0   31
#
# [9172 rows x 6 columns]

# %%
df[sel_cat_cols]
# Out:
#      sex I131_treatment psych on_thyroxine target goitre lithium pregnant  \
# 0      F              f     f            f      -      f       f        f
# 1      F              f     f            f      -      f       f        f
# 2      F              f     f            f      -      f       f        f
# 3      F              f     f            f      -      f       f        f
# 4      F              f     f            f      S      f       f        f
# ...   ..            ...   ...          ...    ...    ...     ...      ...
# 9167   M              f     f            f      -      f       f        f
# 9168   M              f     f            f      -      f       f        f
# 9169   M              f     f            f      I      f       f        f
# 9170   F              f     f            f      -      f       f        f
# 9171   M              f     f            f      -      f       f        f
#
#      tumor referral_source sick thyroid_surgery on_antithyroid_meds
# 0        f           other    f               f                   f
# 1        f           other    f               f                   f
# 2        f           other    f               f                   f
# 3        f           other    f               f                   f
# 4        f           other    f               f                   f
# ...    ...             ...  ...             ...                 ...
# 9167     f             SVI    f               f                   f
# 9168     f             SVI    f               f                   f
# 9169     f             SVI    f               f                   f
# 9170     f           other    f               f                   f
# 9171     f           other    f               f                   f
#
# [9172 rows x 13 columns]

# %%
qual_na_df = df[sel_qual_cols].dropna()
qual_na_df
# Out:
#         FTI   T4U   T3    TSH    TT4  age
# 19     85.0  1.06  2.4   1.50   90.0   36
# 21     96.0  1.08  2.3   1.20  104.0   40
# 22    105.0  0.84  2.1   5.90   88.0   40
# 23     95.0  1.13  2.4   0.05  107.0   77
# 27    106.0  0.87  2.1   0.05   93.0   51
# ...     ...   ...  ...    ...    ...  ...
# 9129   94.0  0.90  1.8   0.73   85.0   65
# 9130  113.0  1.19  2.1   4.10  135.0   65
# 9134   39.0  1.25  1.0  53.00   49.0   74
# 9137   81.0  0.73  1.3   2.30   59.0   42
# 9141  107.0  0.95  1.8   2.40  102.0   42
#
# [5984 rows x 6 columns]

# %%
from data_split import k_fold_split

# %%
complete_vals_df, missing_vals_df = k_fold_split(qual_na_df, k, random_generator)

# %%
complete_vals_df
# Out:
#         FTI   T4U   T3        TSH    TT4      age
# 7881  115.0  1.08  1.5   1.300000  124.0     48.0
# 403   107.0  0.70  2.0   1.300000   75.0     51.0
# 7412   95.0  0.91  2.2  10.000000   86.0     34.0
# 8483  120.0  0.97  2.4   1.800000  116.0     50.0
# 1846  118.0  1.04  2.3   0.800000  124.0     80.0
# ...     ...   ...  ...        ...    ...      ...
# 5710  104.0  1.08  2.0   0.380000  113.0  65511.0
# 682   266.0  0.50  1.9   0.100000  133.0     46.0
# 6393  149.0  1.48  2.4   0.030000  220.0     28.0
# 8767   35.0  0.97  1.7  16.799999   34.0     57.0
# 4333  157.0  0.91  1.8   2.800000  143.0     67.0
#
# [5386 rows x 6 columns]

# %%
missing_vals_df
# Out:
#         FTI   T4U   T3     TSH    TT4   age
# 92    134.0  0.73  0.4    0.20   98.0  88.0
# 312    17.0  0.94  0.2  145.00   16.0  65.0
# 1347  188.0  0.81  2.2    0.10  153.0  33.0
# 4525  145.0  0.96  1.9    0.58  140.0  85.0
# 4328  101.0  0.98  2.3    0.33   99.0  74.0
# ...     ...   ...  ...     ...    ...   ...
# 7528   85.0  1.09  2.5    2.30   93.0  55.0
# 2110   71.0  0.93  2.0    1.80   66.0  42.0
# 3210   97.0  1.06  1.9    1.80  102.0  61.0
# 4874   69.0  1.07  2.4    1.80   73.0  90.0
# 429   127.0  0.97  2.1    0.60  123.0  57.0
#
# [598 rows x 6 columns]

# %%
missing_vals_idxs = set(missing_vals_df.index)

# %%
missing_vals_T3_df = missing_vals_df.copy()
missing_vals_T3_df["T3"] = np.NaN
missing_vals_T3_df
# Out:
#         FTI   T4U  T3     TSH    TT4   age
# 92    134.0  0.73 NaN    0.20   98.0  88.0
# 312    17.0  0.94 NaN  145.00   16.0  65.0
# 1347  188.0  0.81 NaN    0.10  153.0  33.0
# 4525  145.0  0.96 NaN    0.58  140.0  85.0
# 4328  101.0  0.98 NaN    0.33   99.0  74.0
# ...     ...   ...  ..     ...    ...   ...
# 7528   85.0  1.09 NaN    2.30   93.0  55.0
# 2110   71.0  0.93 NaN    1.80   66.0  42.0
# 3210   97.0  1.06 NaN    1.80  102.0  61.0
# 4874   69.0  1.07 NaN    1.80   73.0  90.0
# 429   127.0  0.97 NaN    0.60  123.0  57.0
#
# [598 rows x 6 columns]

# %%
complete_df = pd.concat([complete_vals_df, missing_vals_df])
complete_df
# Out:
#         FTI   T4U   T3   TSH    TT4   age
# 7881  115.0  1.08  1.5   1.3  124.0  48.0
# 403   107.0  0.70  2.0   1.3   75.0  51.0
# 7412   95.0  0.91  2.2  10.0   86.0  34.0
# 8483  120.0  0.97  2.4   1.8  116.0  50.0
# 1846  118.0  1.04  2.3   0.8  124.0  80.0
# ...     ...   ...  ...   ...    ...   ...
# 7528   85.0  1.09  2.5   2.3   93.0  55.0
# 2110   71.0  0.93  2.0   1.8   66.0  42.0
# 3210   97.0  1.06  1.9   1.8  102.0  61.0
# 4874   69.0  1.07  2.4   1.8   73.0  90.0
# 429   127.0  0.97  2.1   0.6  123.0  57.0
#
# [5984 rows x 6 columns]

# %%
T3_df = pd.concat([complete_vals_df, missing_vals_T3_df])
T3_df
# Out:
#         FTI   T4U   T3   TSH    TT4   age
# 7881  115.0  1.08  1.5   1.3  124.0  48.0
# 403   107.0  0.70  2.0   1.3   75.0  51.0
# 7412   95.0  0.91  2.2  10.0   86.0  34.0
# 8483  120.0  0.97  2.4   1.8  116.0  50.0
# 1846  118.0  1.04  2.3   0.8  124.0  80.0
# ...     ...   ...  ...   ...    ...   ...
# 7528   85.0  1.09  NaN   2.3   93.0  55.0
# 2110   71.0  0.93  NaN   1.8   66.0  42.0
# 3210   97.0  1.06  NaN   1.8  102.0  61.0
# 4874   69.0  1.07  NaN   1.8   73.0  90.0
# 429   127.0  0.97  NaN   0.6  123.0  57.0
#
# [5984 rows x 6 columns]

# %%
imputer = KNNImputer(n_neighbors=neighbours)
filled = imputer.fit_transform(T3_df)
df_filled = pd.DataFrame(filled, columns=T3_df.columns, index=T3_df.index)
df_filled["T3 (real)"] = complete_df["T3"]
df_filled["T3 (imputed)"] = df_filled["T3"]
df_filled.drop(["T3"], axis=1, inplace=True)
df_filled
# Out:
#         FTI   T4U   TSH    TT4   age  T3 (real)  T3 (imputed)
# 7881  115.0  1.08   1.3  124.0  48.0        1.5          1.50
# 403   107.0  0.70   1.3   75.0  51.0        2.0          2.00
# 7412   95.0  0.91  10.0   86.0  34.0        2.2          2.20
# 8483  120.0  0.97   1.8  116.0  50.0        2.4          2.40
# 1846  118.0  1.04   0.8  124.0  80.0        2.3          2.30
# ...     ...   ...   ...    ...   ...        ...           ...
# 7528   85.0  1.09   2.3   93.0  55.0        2.5          2.05
# 2110   71.0  0.93   1.8   66.0  42.0        2.0          2.40
# 3210   97.0  1.06   1.8  102.0  61.0        1.9          2.10
# 4874   69.0  1.07   1.8   73.0  90.0        2.4          1.40
# 429   127.0  0.97   0.6  123.0  57.0        2.1          1.65
#
# [5984 rows x 7 columns]
